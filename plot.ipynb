# %%
import matplotlib.pyplot as plt 
import pandas as pd
# Out:
# C:\Users\Stou\AppData\Local\Programs\Python\Python37\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
plt.plot([0.9,0.85,0.8,0.75,0.7,0.65,0.6,0.55,0.5,0.45,0.4],[5.549,6.776,9.085,13.496,18.240,29.988,50.518,88.903,159.896,288.750,499.947],'-or',label="Eclat")
plt.plot([0.9,0.85,0.8,0.75,0.7,0.65,0.6,0.55,0.5,0.45,0.4],[47.791,48.933,48.818,51.817,53.955,59.932,72.580,98.020,153.929,275.029,540.904],'-o',label="Apriori")
plt.xlabel("Frequency (%)")
plt.ylabel("Seconds")
plt.legend()
plt.title("Accident dataset")
plt.savefig("accident.png")

# %%
plt.plot([0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2],[0.073256,0.077681,0.081152,0.093565,0.129597,0.252392,0.741846,9.776594],'-or',label="Eclat")
plt.plot([0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2],[0.160,0.162,0.162,0.170,0.197,0.316,1.091,67.806],'-o',label="Apriori")
plt.xlabel("Frequency (%)")
plt.ylabel("Seconds")
plt.legend()
plt.title("Mushroom dataset")
plt.savefig("mushroom.png")

# %%
plt.plot([0.9,0.8,0.7,0.6],[0.165038,1.521344,8.657954,43.286767],'-or',label="Eclat")
plt.plot([0.9,0.8,0.7,0.6], [0.187,3.251,61.361,1421.715],'-o',label="Apriori")
plt.xlabel("Frequency (%)")
plt.ylabel("Seconds")
plt.legend()
plt.title("Chess dataset")
plt.savefig("chess.png")
